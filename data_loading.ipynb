# %%
# !pip install sqlalchemy
# !pip install mysql-connector-python
from sqlalchemy import create_engine
engine = create_engine('mysql+mysqlconnector://root:KjUXxjW.7R_7iC47U4R8@localhost/home_credit')

# %%
# !pip install pandas
import pandas as pd

path = 'C:/Users/anton/Downloads/home_credit/'

tables = {
    'previous_application': path + 'previous_application.csv',
    'installments_payments': path + 'installments_payments.csv',
    'credit_card_balance': path + 'credit_card_balance.csv',
    'bureau_balance': path + 'bureau_balance.csv',
    'bureau': path + 'bureau.csv',
    'application_train': path + 'application_train.csv',
    'POS_CASH_balance': path + 'POS_CASH_balance.csv',
}

for tablename, file in tables.items():
    print('Load ' + tablename + '...')
    df = pd.read_csv(file)
    df.to_sql(tablename, engine, if_exists='replace',
        index=False, chunksize=10000)
    print('Finished: ' + tablename + ' (' + str(len(df)) + ' Rows)')
# Out:
# Load previous_application...
# Finished: previous_application (1670214 Rows)
# Load installments_payments...
# Finished: installments_payments (13605401 Rows)
# Load credit_card_balance...
# Finished: credit_card_balance (3840312 Rows)
# Load bureau_balance...
# Finished: bureau_balance (27299925 Rows)
# Load bureau...
# Finished: bureau (1716428 Rows)
# Load application_train...
# Finished: application_train (307511 Rows)
# Load POS_CASH_balance...
# C:\Users\anton\AppData\Local\Temp\ipykernel_10652\212877846.py:19: UserWarning: The provided table name 'POS_CASH_balance' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(tablename, engine, if_exists='replace',
# Finished: POS_CASH_balance (10001358 Rows)
